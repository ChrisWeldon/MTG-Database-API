# %%
import sys, os
sys.path.append(os.path.abspath('../src'))
from Database import Database
import pandas as pd

# %%
db = Database()

# %%
def max_decks(num):
    if num>16:
        return 16
    else:
        return num
standard_plays = db.getCardSeriesDataFrame(card, format='standard')
standard_plays['deck_nums'] = standard_plays['deck_nums'].apply(max_decks)

# %%
pio_plays = db.getCardSeriesDataFrame(card, format='pioneer')
pio_plays['deck_nums'] = pio_plays['deck_nums'].apply(max_decks)

# %%
standard_events = db.getTournamentSeriesDataFrame(format='standard')
standard_events = standard_events.set_index('date').groupby('date').min()

# %%
pio_events = db.getTournamentSeriesDataFrame(format='pioneer')
pio_events = pio_events.set_index('date').groupby('date').min()

# %%
standard_occ = standard_plays[['date', 'tot_occ', 'deck_nums']].set_index('date').groupby('date').sum()
standard_occ['norm_occ']  = standard_occ['tot_occ']/standard_occ['deck_nums']

# %%
pio_occ = pio_plays[['date', 'tot_occ', 'deck_nums']].set_index('date').groupby('date').sum()
pio_occ['norm_occ']  = pio_occ['tot_occ']/pio_occ['deck_nums']

# %%
std_occ_series = pd.merge(standard_events, standard_occ, how='left', left_index=True, right_index=True).fillna(0)
std_occ_series = std_occ_series.drop(['url','format','id'], axis=1)

# %%
pio_occ_series = pd.merge(pio_events, pio_occ, how='left', left_index=True, right_index=True).fillna(0)
pio_occ_series = pio_occ_series.drop(['url','format','id'], axis=1)

# %%
pf = db.getPriceSeriesDataFrame(card)
pf = pf.set_index('date')

# %%
time_series = pd.merge(pf, standard_occ, how='left', left_index=True, right_index=True)
time_series = pd.merge(time_series, pio_occ, how='left', left_index=True, right_index=True)
time_series = time_series.ffill()
# Out:
#                       title  price    tix              rowid  echo_id  \
# date
# 2019-09-28  Brazen Borrower  17.96  18.54  112518:2019-09-28   112518
# 2019-09-29  Brazen Borrower  17.50  14.46  112518:2019-09-29   112518
# 2019-09-30  Brazen Borrower  16.57   9.02  112518:2019-09-30   112518
# 2019-10-01  Brazen Borrower  16.89  12.39  112518:2019-10-01   112518
# 2019-10-02  Brazen Borrower  16.98  12.63  112518:2019-10-02   112518
# ...                     ...    ...    ...                ...      ...
# 2020-03-10  Brazen Borrower  22.34  45.51  112518:2020-03-10   112518
# 2020-03-11  Brazen Borrower  21.85  43.18  112518:2020-03-11   112518
# 2020-03-12  Brazen Borrower  21.85  43.18  112518:2020-03-12   112518
# 2020-03-13  Brazen Borrower  20.34  42.82  112518:2020-03-13   112518
# 2020-03-14  Brazen Borrower  20.23  42.82  112518:2020-03-14   112518
#
#             tot_occ_x  deck_nums_x  norm_occ_x  tot_occ_y  deck_nums_y  \
# date
# 2019-09-28        3.0          8.0    0.375000        NaN          NaN
# 2019-09-29        3.0          8.0    0.375000        NaN          NaN
# 2019-09-30        3.0         15.0    0.200000        NaN          NaN
# 2019-10-01        3.0         15.0    0.200000        NaN          NaN
# 2019-10-02        3.0         15.0    0.200000        NaN          NaN
# ...               ...          ...         ...        ...          ...
# 2020-03-10       17.0         14.0    1.214286        3.0         16.0
# 2020-03-11        9.0         13.0    0.692308        6.0         16.0
# 2020-03-12       19.0         19.0    1.000000       11.0         32.0
# 2020-03-13       19.0         19.0    1.000000       11.0         32.0
# 2020-03-14       19.0         19.0    1.000000       11.0         32.0
#
#             norm_occ_y
# date
# 2019-09-28         NaN
# 2019-09-29         NaN
# 2019-09-30         NaN
# 2019-10-01         NaN
# 2019-10-02         NaN
# ...                ...
# 2020-03-10     0.18750
# 2020-03-11     0.37500
# 2020-03-12     0.34375
# 2020-03-13     0.34375
# 2020-03-14     0.34375
#
# [169 rows x 11 columns]

# %%
def load_formatted_plays(card):
    def max_decks(num):
        if num>16:
            return 16
        else:
            return num
    std_plays = db.getCardSeriesDataFrame(card, format='standard')
    std_plays['deck_nums'] = std_plays['deck_nums'].apply(max_decks)
    pio_plays = db.getCardSeriesDataFrame(card, format='pioneer')
    pio_plays['deck_nums'] = pio_plays['deck_nums'].apply(max_decks)
    
    std_events = db.getTournamentSeriesDataFrame(format='standard')
    std_events = std_events.set_index('date').groupby('date').min()
    pio_events = db.getTournamentSeriesDataFrame(format='pioneer')
    pio_events = pio_events.set_index('date').groupby('date').min()
    
    std_occ = std_plays[['date', 'tot_occ', 'deck_nums']].set_index('date').groupby('date').sum()
    std_occ['norm_occ_std']  = std_occ['tot_occ']/std_occ['deck_nums']
    pio_occ = pio_plays[['date', 'tot_occ', 'deck_nums']].set_index('date').groupby('date').sum()
    pio_occ['norm_occ_pio']  = pio_occ['tot_occ']/pio_occ['deck_nums']
    
    std_occ_series = pd.merge(std_events, std_occ, how='left', left_index=True, right_index=True).fillna(0)
    std_occ_series = std_occ_series.drop(['url','format','id'], axis=1)
    pio_occ_series = pd.merge(pio_events, pio_occ, how='left', left_index=True, right_index=True).fillna(0)
    pio_occ_series = pio_occ_series.drop(['url','format','id'], axis=1)
    
    pf = db.getPriceSeriesDataFrame(card)
    pf = pf.set_index('date')
    
    time_series = pd.merge(pf, std_occ, how='left', left_index=True, right_index=True)
    time_series = pd.merge(time_series, pio_occ, how='left', left_index=True, right_index=True)
    time_series = time_series.ffill()
    
    
    return time_series

# %%
sys.path.append('../env/lib/python3.7/sites_pacakges')
import matplotlib.dates as mdates
from scipy import integrate
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt


def show_raw_and_prices(df):

    
    #plot data
    
    fig, ax = plt.subplots(figsize=(15,7))
    ax = df.plot(y='tix', ax=ax)
    #ax = df.plot(y='price', ax=ax)
    ax = df.plot(y='norm_occ_std', ax=ax, style='--', alpha=1)
    ax = df.plot(y='norm_occ_pio', ax=ax, style='--', alpha=1)
    
    #set ticks every week
    ax.xaxis.set_major_locator(mdates.WeekdayLocator())
    #set major ticks format
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))
    ax.grid()
    plt.gcf().autofmt_xdate()
    plt.show()

# %%
db = Database()
card = db.getCardByTitle('Brazen Borrower')
time_series = load_formatted_plays(card)

# %%
show_raw_and_prices(time_series)

# %%
time_series = time_series[['tix', 'norm_occ_std', 'norm_occ_pio']].fillna(0)

# %%
time_series['tix_mean'] = time_series['tix'].rolling(window=4).mean().bfill()

# %%
from pandas.plotting import lag_plot

import warnings

import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import numpy as np
import pandas as pd

plt.ion()

mpl.rcParams['axes.labelsize'] = 20
mpl.rcParams['axes.titlesize'] = 24
mpl.rcParams['figure.figsize'] = (20, 8)
mpl.rcParams['xtick.labelsize'] = 14
mpl.rcParams['ytick.labelsize'] = 14
mpl.rcParams['legend.fontsize'] = 14

# %%
time_series['d_tix'] = time_series['tix'].diff().fillna(0)

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class Horizonizer(BaseEstimator, TransformerMixin):
    def __init__(self, columns=[], windows=[], drop_t0=True):
        self.windows = windows
        self.columns = columns
        self.drop_t0 = drop_t0
        assert len(columns) == len(windows), 'windows and columns are not same length'
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):    
        for c in range(len(self.columns)):
            subdf_cols = []
            series = X[self.columns[c]]
            for i in range(self.windows[c]):
                subdf_cols.append(self.columns[c] + '_t-' + str(i))

            subdf = pd.DataFrame(columns = subdf_cols)
            
            for i in range(len(series)):
                if i < self.windows[c]:
                    subdf.loc[i] = [series[i-j] for j in range(i+1)] + [None for k in range(1, self.windows[c]-i)]
                else:
                    subdf.loc[i] = [series[i-j] for j in range(self.windows[c])]
                    
            if len(X.index) > 0:
                subdf.set_index(X.index, inplace=True)
            
            if self.drop_t0:
                subdf = subdf.drop(self.columns[c] + '_t-' + str(0), axis=1)
                X = X.drop(self.columns[c], axis=1)
            X = pd.concat([X, subdf], axis=1)
            
        return X

# %%
from datetime import datetime
class Forecaster(BaseEstimator, TransformerMixin):
    def __init__(self, forecast_len=14, method=LinearRegression):
        self.forecast_len = forecast_len
        self.method = method
        self.forecast_models = []
        
    def fit(self, X, y=None):
        self.y = y.copy()
        for i in range(self.forecast_len):
            lin_reg = self.method()
            
            lin_reg.fit(X[:-(i+1)],y.shift(-1*(i+1))[:-(i+1)])
            
            self.forecast_models.append(lin_reg)
        return self
    
    def transform(self, X):
        return X
        
    def forecast(self, X, start=date(2020,3,10), forecast_col='t+0'):
        columns =['forecast']
        for m in range(len(self.forecast_models)):
            columns.append('t+' + str(m))
        
        forecast_y = pd.DataFrame(columns=columns)
        
        for i in range(X.shape[0]):
            predictions = [None]
            #print(X.iloc[i])
            
            for model in self.forecast_models:
                predictions.append(model.predict(X.iloc[i].values.reshape(1,-1))[0])
            forecast_y.loc[i] = predictions
        
        forecast_y.set_index(X.index, inplace=True)
        
        index = pd.date_range(pd.to_datetime(forecast_y.iloc[[-1]].index).date[0], periods=28, freq='D')
        
        forecast_y = pd.concat([forecast_y, pd.DataFrame(index=index.date)])
        
        for i, row in forecast_y.iterrows():
            forecast_y.at[i,'forecast'] = forecast_y.at[i, forecast_col]
            if i > start:
                for j in range(len(self.forecast_models)):
                    date_index = i + timedelta(days=j)
                    forecast_y.at[date_index,'forecast'] = forecast_y.at[date_index, 't+'+str(j)]
                        
                break
        
        plt.plot(forecast_y['forecast'])
        plt.axvline(x=start, linestyle='--', color='k')
        plt.grid()
        return(forecast_y)

# %%
from datetime import datetime
class Forecaster(BaseEstimator, TransformerMixin):
    def __init__(self, forecast_len=14, method=LinearRegression):
        self.forecast_len = forecast_len
        self.method = method
        self.forecast_models = []
        
    def fit(self, X, y=None):
        self.y = y.copy()
        for i in range(self.forecast_len):
            lin_reg = self.method()
            
            print(X.index[:-(i+1)])
            print(y.shift(-1*(i+1)).index[:-(i+1)])
            lin_reg.fit(X[:-(i+1)],y.shift(-1*(i+1))[:-(i+1)])
            
            self.forecast_models.append({"t+" + str(i+1):lin_reg})
        return self
    
    def transform(self, X):
        return X
        
    def forecast(self, X):
        columns = []
        index = []
        date = X.index[-1]
        for i in range(self.forecast_len):
            columns.append("fore_"+str(i+1))
            index.append(date+ timedelta(days=i+1))
        
        forecast = pd.DataFrame(index = index, columns=columns)
        
        data = X.iloc[-1].values.reshape(1,-1)
        date = X.index[-1]
        print(date)
        col = [model.predict(data) for model in self.forecast_models]
        
        return pd.Series(col, index=index)

# %%
horizon_pipeline = Horizonizer( columns=['d_tix', 'norm_occ_std', 'norm_occ_pio'], windows=[7,7,7])
df = horizon_pipeline.transform(time_series).bfill()

# %%
from datetime import date
start_idx = date(2020,2, 15)
X, y = df.copy().drop('tix', axis=1), df['tix']

# %%
forecaster = Forecaster(forecast_len=14)
forecaster.fit(X[:start_idx],y[:start_idx])
# Out:
# Index([2019-09-28, 2019-09-29, 2019-09-30, 2019-10-01, 2019-10-02, 2019-10-03,
#        2019-10-04, 2019-10-05, 2019-10-06, 2019-10-07,
#        ...
#        2020-02-05, 2020-02-06, 2020-02-07, 2020-02-08, 2020-02-09, 2020-02-10,
#        2020-02-11, 2020-02-12, 2020-02-13, 2020-02-14],
#       dtype='object', name='date', length=140)
# Index([2019-09-28, 2019-09-29, 2019-09-30, 2019-10-01, 2019-10-02, 2019-10-03,
#        2019-10-04, 2019-10-05, 2019-10-06, 2019-10-07,
#        ...
#        2020-02-05, 2020-02-06, 2020-02-07, 2020-02-08, 2020-02-09, 2020-02-10,
#        2020-02-11, 2020-02-12, 2020-02-13, 2020-02-14],
#       dtype='object', name='date', length=140)
# Index([2019-09-28, 2019-09-29, 2019-09-30, 2019-10-01, 2019-10-02, 2019-10-03,
#        2019-10-04, 2019-10-05, 2019-10-06, 2019-10-07,
#        ...
#        2020-02-04, 2020-02-05, 2020-02-06, 2020-02-07, 2020-02-08, 2020-02-09,
#        2020-02-10, 2020-02-11, 2020-02-12, 2020-02-13],
#       dtype='object', name='date', length=139)
# Index([2019-09-28, 2019-09-29, 2019-09-30, 2019-10-01, 2019-10-02, 2019-10-03,
#        2019-10-04, 2019-10-05, 2019-10-06, 2019-10-07,
#        ...
#        2020-02-04, 2020-02-05, 2020-02-06, 2020-02-07, 2020-02-08, 2020-02-09,
#        2020-02-10, 2020-02-11, 2020-02-12, 2020-02-13],
#       dtype='object', name='date', length=139)
# Index([2019-09-28, 2019-09-29, 2019-09-30, 2019-10-01, 2019-10-02, 2019-10-03,
#        2019-10-04, 2019-10-05, 2019-10-06, 2019-10-07,
#        ...
#        2020-02-03, 2020-02-04, 2020-02-05, 2020-02-06, 2020-02-07, 2020-02-08,
#        2020-02-09, 2020-02-10, 2020-02-11, 2020-02-12],
#       dtype='object', name='date', length=138)
# Index([2019-09-28, 2019-09-29, 2019-09-30, 2019-10-01, 2019-10-02, 2019-10-03,
#        2019-10-04, 2019-10-05, 2019-10-06, 2019-10-07,
#        ...
#        2020-02-03, 2020-02-04, 2020-02-05, 2020-02-06, 2020-02-07, 2020-02-08,
#        2020-02-09, 2020-02-10, 2020-02-11, 2020-02-12],
#       dtype='object', name='date', length=138)
# Index([2019-09-28, 2019-09-29, 2019-09-30, 2019-10-01, 2019-10-02, 2019-10-03,
#        2019-10-04, 2019-10-05, 2019-10-06, 2019-10-07,
#        ...
#        2020-02-02, 2020-02-03, 2020-02-04, 2020-02-05, 2020-02-06, 2020-02-07,
#        2020-02-08, 2020-02-09, 2020-02-10, 2020-02-11],
#       dtype='object', name='date', length=137)
# Index([2019-09-28, 2019-09-29, 2019-09-30, 2019-10-01, 2019-10-02, 2019-10-03,
#        2019-10-04, 2019-10-05, 2019-10-06, 2019-10-07,
#        ...
#        2020-02-02, 2020-02-03, 2020-02-04, 2020-02-05, 2020-02-06, 2020-02-07,
#        2020-02-08, 2020-02-09, 2020-02-10, 2020-02-11],
#       dtype='object', name='date', length=137)
# Index([2019-09-28, 2019-09-29, 2019-09-30, 2019-10-01, 2019-10-02, 2019-10-03,
#        2019-10-04, 2019-10-05, 2019-10-06, 2019-10-07,
#        ...
#        2020-02-01, 2020-02-02, 2020-02-03, 2020-02-04, 2020-02-05, 2020-02-06,
#        2020-02-07, 2020-02-08, 2020-02-09, 2020-02-10],
#       dtype='object', name='date', length=136)
# Index([2019-09-28, 2019-09-29, 2019-09-30, 2019-10-01, 2019-10-02, 2019-10-03,
#        2019-10-04, 2019-10-05, 2019-10-06, 2019-10-07,
#        ...
#        2020-02-01, 2020-02-02, 2020-02-03, 2020-02-04, 2020-02-05, 2020-02-06,
#        2020-02-07, 2020-02-08, 2020-02-09, 2020-02-10],
#       dtype='object', name='date', length=136)
# Index([2019-09-28, 2019-09-29, 2019-09-30, 2019-10-01, 2019-10-02, 2019-10-03,
#        2019-10-04, 2019-10-05, 2019-10-06, 2019-10-07,
#        ...
#        2020-01-31, 2020-02-01, 2020-02-02, 2020-02-03, 2020-02-04, 2020-02-05,
#        2020-02-06, 2020-02-07, 2020-02-08, 2020-02-09],
#       dtype='object', name='date', length=135)
# Index([2019-09-28, 2019-09-29, 2019-09-30, 2019-10-01, 2019-10-02, 2019-10-03,
#        2019-10-04, 2019-10-05, 2019-10-06, 2019-10-07,
#        ...
#        2020-01-31, 2020-02-01, 2020-02-02, 2020-02-03, 2020-02-04, 2020-02-05,
#        2020-02-06, 2020-02-07, 2020-02-08, 2020-02-09],
#       dtype='object', name='date', length=135)
# Index([2019-09-28, 2019-09-29, 2019-09-30, 2019-10-01, 2019-10-02, 2019-10-03,
#        2019-10-04, 2019-10-05, 2019-10-06, 2019-10-07,
#        ...
#        2020-01-30, 2020-01-31, 2020-02-01, 2020-02-02, 2020-02-03, 2020-02-04,
#        2020-02-05, 2020-02-06, 2020-02-07, 2020-02-08],
#       dtype='object', name='date', length=134)
# Index([2019-09-28, 2019-09-29, 2019-09-30, 2019-10-01, 2019-10-02, 2019-10-03,
#        2019-10-04, 2019-10-05, 2019-10-06, 2019-10-07,
#        ...
#        2020-01-30, 2020-01-31, 2020-02-01, 2020-02-02, 2020-02-03, 2020-02-04,
#        2020-02-05, 2020-02-06, 2020-02-07, 2020-02-08],
#       dtype='object', name='date', length=134)
# Index([2019-09-28, 2019-09-29, 2019-09-30, 2019-10-01, 2019-10-02, 2019-10-03,
#        2019-10-04, 2019-10-05, 2019-10-06, 2019-10-07,
#        ...
#        2020-01-29, 2020-01-30, 2020-01-31, 2020-02-01, 2020-02-02, 2020-02-03,
#        2020-02-04, 2020-02-05, 2020-02-06, 2020-02-07],
#       dtype='object', name='date', length=133)
# Index([2019-09-28, 2019-09-29, 2019-09-30, 2019-10-01, 2019-10-02, 2019-10-03,
#        2019-10-04, 2019-10-05, 2019-10-06, 2019-10-07,
#        ...
#        2020-01-29, 2020-01-30, 2020-01-31, 2020-02-01, 2020-02-02, 2020-02-03,
#        2020-02-04, 2020-02-05, 2020-02-06, 2020-02-07],
#       dtype='object', name='date', length=133)
# Index([2019-09-28, 2019-09-29, 2019-09-30, 2019-10-01, 2019-10-02, 2019-10-03,
#        2019-10-04, 2019-10-05, 2019-10-06, 2019-10-07,
#        ...
#        2020-01-28, 2020-01-29, 2020-01-30, 2020-01-31, 2020-02-01, 2020-02-02,
#        2020-02-03, 2020-02-04, 2020-02-05, 2020-02-06],
#       dtype='object', name='date', length=132)
# Index([2019-09-28, 2019-09-29, 2019-09-30, 2019-10-01, 2019-10-02, 2019-10-03,
#        2019-10-04, 2019-10-05, 2019-10-06, 2019-10-07,
#        ...
#        2020-01-28, 2020-01-29, 2020-01-30, 2020-01-31, 2020-02-01, 2020-02-02,
#        2020-02-03, 2020-02-04, 2020-02-05, 2020-02-06],
#       dtype='object', name='date', length=132)
# Index([2019-09-28, 2019-09-29, 2019-09-30, 2019-10-01, 2019-10-02, 2019-10-03,
#        2019-10-04, 2019-10-05, 2019-10-06, 2019-10-07,
#        ...
#        2020-01-27, 2020-01-28, 2020-01-29, 2020-01-30, 2020-01-31, 2020-02-01,
#        2020-02-02, 2020-02-03, 2020-02-04, 2020-02-05],
#       dtype='object', name='date', length=131)
# Index([2019-09-28, 2019-09-29, 2019-09-30, 2019-10-01, 2019-10-02, 2019-10-03,
#        2019-10-04, 2019-10-05, 2019-10-06, 2019-10-07,
#        ...
#        2020-01-27, 2020-01-28, 2020-01-29, 2020-01-30, 2020-01-31, 2020-02-01,
#        2020-02-02, 2020-02-03, 2020-02-04, 2020-02-05],
#       dtype='object', name='date', length=131)
# Index([2019-09-28, 2019-09-29, 2019-09-30, 2019-10-01, 2019-10-02, 2019-10-03,
#        2019-10-04, 2019-10-05, 2019-10-06, 2019-10-07,
#        ...
#        2020-01-26, 2020-01-27, 2020-01-28, 2020-01-29, 2020-01-30, 2020-01-31,
#        2020-02-01, 2020-02-02, 2020-02-03, 2020-02-04],
#       dtype='object', name='date', length=130)
# Index([2019-09-28, 2019-09-29, 2019-09-30, 2019-10-01, 2019-10-02, 2019-10-03,
#        2019-10-04, 2019-10-05, 2019-10-06, 2019-10-07,
#        ...
#        2020-01-26, 2020-01-27, 2020-01-28, 2020-01-29, 2020-01-30, 2020-01-31,
#        2020-02-01, 2020-02-02, 2020-02-03, 2020-02-04],
#       dtype='object', name='date', length=130)
# Index([2019-09-28, 2019-09-29, 2019-09-30, 2019-10-01, 2019-10-02, 2019-10-03,
#        2019-10-04, 2019-10-05, 2019-10-06, 2019-10-07,
#        ...
#        2020-01-25, 2020-01-26, 2020-01-27, 2020-01-28, 2020-01-29, 2020-01-30,
#        2020-01-31, 2020-02-01, 2020-02-02, 2020-02-03],
#       dtype='object', name='date', length=129)
# Index([2019-09-28, 2019-09-29, 2019-09-30, 2019-10-01, 2019-10-02, 2019-10-03,
#        2019-10-04, 2019-10-05, 2019-10-06, 2019-10-07,
#        ...
#        2020-01-25, 2020-01-26, 2020-01-27, 2020-01-28, 2020-01-29, 2020-01-30,
#        2020-01-31, 2020-02-01, 2020-02-02, 2020-02-03],
#       dtype='object', name='date', length=129)
# Index([2019-09-28, 2019-09-29, 2019-09-30, 2019-10-01, 2019-10-02, 2019-10-03,
#        2019-10-04, 2019-10-05, 2019-10-06, 2019-10-07,
#        ...
#        2020-01-24, 2020-01-25, 2020-01-26, 2020-01-27, 2020-01-28, 2020-01-29,
#        2020-01-30, 2020-01-31, 2020-02-01, 2020-02-02],
#       dtype='object', name='date', length=128)
# Index([2019-09-28, 2019-09-29, 2019-09-30, 2019-10-01, 2019-10-02, 2019-10-03,
#        2019-10-04, 2019-10-05, 2019-10-06, 2019-10-07,
#        ...
#        2020-01-24, 2020-01-25, 2020-01-26, 2020-01-27, 2020-01-28, 2020-01-29,
#        2020-01-30, 2020-01-31, 2020-02-01, 2020-02-02],
#       dtype='object', name='date', length=128)
# Index([2019-09-28, 2019-09-29, 2019-09-30, 2019-10-01, 2019-10-02, 2019-10-03,
#        2019-10-04, 2019-10-05, 2019-10-06, 2019-10-07,
#        ...
#        2020-01-23, 2020-01-24, 2020-01-25, 2020-01-26, 2020-01-27, 2020-01-28,
#        2020-01-29, 2020-01-30, 2020-01-31, 2020-02-01],
#       dtype='object', name='date', length=127)
# Index([2019-09-28, 2019-09-29, 2019-09-30, 2019-10-01, 2019-10-02, 2019-10-03,
#        2019-10-04, 2019-10-05, 2019-10-06, 2019-10-07,
#        ...
#        2020-01-23, 2020-01-24, 2020-01-25, 2020-01-26, 2020-01-27, 2020-01-28,
#        2020-01-29, 2020-01-30, 2020-01-31, 2020-02-01],
#       dtype='object', name='date', length=127)
# Forecaster(forecast_len=14,
#            method=<class 'sklearn.linear_model._base.LinearRegression'>)

# %%
plt.plot(y)
plt.plot(forecaster.forecast(X[:start_idx]))
# Out:
# 2020-02-25

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-420-0e4c7beb0d02> in <module>
# ----> 1 time_series.plot(['tix'])
#
# ~/Projects/MTG_Database/env/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     811                     x = data_cols[x]
#     812                 elif not isinstance(data[x], ABCSeries):
# --> 813                     raise ValueError("x must be a label or position")
#     814                 data = data.set_index(x)
#     815             if y is not None:
#
# ValueError: x must be a label or position
